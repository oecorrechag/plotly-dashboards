# %% [markdown]
# # 0.2.0 Styling Dash Apps

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import plotly.express as px

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append("../") 

import utils.paths as path
from utils.paths2 import direcciones

# %% [markdown]
# # 0.2.2 Adding logos and notes
#
# ![image.png](attachment:image.png)
#
# # 0.2.3 Adding an HTML list to Dash
#
# ![image.png](attachment:image-2.png)
#
# # 0.2.5 Styling a Dash app with CSS
#
# ![image.png](attachment:image-3.png)
#
# # 0.2.6 Switching to Darkmode
#
# ![image.png](attachment:image-4.png)
#
# # 0.2.7 Practicing placement
#
# Which of these would cause an object with this CSS to appear beside another?
#
# R:/ "'display': 'inline-block'"
#
# # 0.2.8 A refined sales dashboard
#
# ![image.png](attachment:image-5.png)
#
# # 0.2.9 A refined sales dashboard
#
# ![image.png](attachment:image-7.png)
#
# # 0.2.10 Controlling object layout
#
# ![image.png](attachment:image-6.png)

# %%
print('ok_')
