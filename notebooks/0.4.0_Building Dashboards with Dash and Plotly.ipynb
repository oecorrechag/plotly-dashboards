# %% [markdown]
# # 0.4.0 Building Dashboards with Dash and Plotly

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import plotly.express as px

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append("../") 

import utils.paths as path
from utils.paths2 import direcciones

# %% [markdown]
# ## 0.4.2 Generate key stats on hover
#
# ![image.png](attachment:image.png)
#
# ## 0.4.3 Hover to update another plot
#
# ![image.png](attachment:image-2.png)
#
# ## 0.4.4 Click to update another plot
#
# ![image.png](attachment:image-3.png)
#
# ## 0.4.7 Conditional dropdown options
#
# ![image.png](attachment:image-4.png)
#
# ## 0.4.9 Interactive key stats table
#
# ![image.png](attachment:image-5.png)
#
# ## 0.4.10 Paginating a key stats table
#
# ![image.png](attachment:image-6.png)
#
# ## 0.4.12 Enhancing the sales dashboard
#
# ![image.png](attachment:image-7.png)
#
# ## 0.4.14 Styling a key stats table
#
# ![image.png](attachment:image-8.png)
#
# ## 0.4.15 Interactive sales dashboard tables
#
# ![image.png](attachment:image-9.png)

# %%
print('ok_')
