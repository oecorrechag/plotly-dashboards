# %% [markdown]
# # 0.3.0 Interactivity with Callbacks and Components

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import plotly.express as px

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append("../") 

import utils.paths as path
from utils.paths2 import direcciones

# %% [markdown]
# # 0.3.2 A dropdown for sales by country
#
# ![image.png](attachment:image.png)
#
# # 0.3.3 Fixing a broken dashboard
#
# ![image.png](attachment:image-2.png)
#
# # 0.3.5 Date picker for sales data
#
# ![image.png](attachment:image-3.png)
#
# # 0.3.6 Date picker for sales data
#
# ![image.png](attachment:image-4.png)
#
# # 0.3.7 Slider for sales data
#
# ![image.png](attachment:image-5.png)
#
# # 0.3.9 Re-using Dash components
#
# ![image.png](attachment:image-6.png)
#
# # 0.3.10 DRY-styling Dash components
#
# ![image.png](attachment:image-7.png)
#
# # 0.3.11 Searching product descriptions
#
# ![image.png](attachment:image-8.png)
#
# # 0.3.12 Analyzing top customer locations
#
# ![image.png](attachment:image-9.png)

# %%
print('ok_')
